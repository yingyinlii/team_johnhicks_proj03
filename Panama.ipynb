# %%
Panama_Data = '1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw'

# %%
import pandas as pd
import numpy as np
from eep153_tools.sheets import read_sheets
p = read_sheets(Panama_Data,sheet='Food Prices')
#p.columns = p.iloc[0]
p.columns.name = 't'
#p = p.drop(labels=0,axis=0).set_index(['j','u'])
#p.columns.name = 'm'
#p.transpose()
p = p.transpose()
p.columns = p.iloc[0]
#p.columns.name = 'i'
p =p.rename(columns = {'j': 'm'})
p.iloc[3:]
# Out:
#                         m Aceite Vegetal Aceite Vegetal Aceite Vegetal  \
# t
# 1997             Chíriqui           3.25            0.1           1.35
# 1997                Coclé           2.99            0.1            1.3
# 1997                Colón           3.25            0.1           1.34
# 1997               Darién            3.2           0.25            1.4
# 1997              Herrera            3.6           0.25            1.3
# 1997           Los Santos            3.1            0.1           1.35
# 1997               Panamá           2.99            0.1           1.35
# 1997             Veraguas           2.95            0.1            1.3
# 2003       Bocas del Toro
# 2003             Chíriqui
# 2003                Coclé
# 2003                Colón
# 2003       Comarca Emberá
# 2003  Comarca Ngobe Bugle
# 2003  Comarca de San Blas
# 2003               Darién
# 2003              Herrera
# 2003           Los Santos
# 2003               Panamá
# 2003             Veraguas
#
#      Aceite Vegetal Aceite Vegetal  Aceite Vegetal Aceite Vegetal  \
# t
# 1997                          5.95                           1.35
# 1997                           5.9                          1.375
# 1997                          5.75
# 1997                          4.85                          1.525
# 1997           2.09           5.76                            1.3
# 1997                          5.99                            1.3
# 1997            7.8            5.9                           1.35
# 1997                          5.86                           1.35
# 2003                   4.800000191
# 2003                         4.875
# 2003                           4.5
# 2003                    4.75999999  0.002212389381
# 2003                           6.5
# 2003                   6.699999809
# 2003                             5  0.002400000095
# 2003                   5.599999905  0.003539823009
# 2003                   4.699999809
# 2003                   4.699999809
# 2003                           4.5  0.002212389381
# 2003                   4.535000086
#
#      Aceite Vegetal Aceite Vegetal  ... Zapallo / Chayote Zapallo / Chayote  \
# t                                   ...
# 1997                         1.325  ...                                 0.1
# 1997                         1.275  ...              0.25              0.15
# 1997                          0.85  ...                                0.25
# 1997                           1.4  ...
# 1997                          1.35  ...                               0.275
# 1997           1.47           0.85  ...                                0.15
# 1997          3.175           1.24  ...              0.25               0.2
# 1997                          0.85  ...                               0.125
# 2003    1.250000017                 ...
# 2003    1.250000033                 ...
# 2003    1.302777784                 ...
# 2003    1.326666673                 ...
# 2003    1.333333333                 ...
# 2003    1.799999952                 ...
# 2003    1.333333333                 ...
# 2003    1.388888926                 ...
# 2003    1.333333333                 ...
# 2003    1.333333333                 ...
# 2003    1.305555537                 ...
# 2003    1.333333333                 ...
#
#      Zapallo / Chayote Ñame             Ñame           Ñame  Ñame  \
# t
# 1997     0.08441558442
# 1997      0.2012987013
# 1997     0.04545454545
# 1997
# 1997     0.06493506494
# 1997     0.07142857143
# 1997      0.1298701299                                       0.65
# 1997
# 2003                                          0.02083333395
# 2003                                          0.04500000067
# 2003
# 2003                         0.0008810572819  0.04374999925
# 2003
# 2003
# 2003
# 2003                                          0.01249999967
# 2003
# 2003                                                 0.0625
# 2003                          0.001948529307  0.03749999901
# 2003                                          0.04270833234
#
#               Ñame   Ñame           Ñame
# t
# 1997           0.4   0.15  0.03896103896
# 1997           0.5    0.5
# 1997           0.4    0.6  0.06493506494
# 1997          0.15
# 1997           0.4
# 1997           0.4          0.4155844156
# 1997           0.5  0.375   0.1168831169
# 1997           0.5
# 2003   0.400000006
# 2003  0.4766666691
# 2003  0.4499999881
# 2003  0.4000000159
# 2003          0.75
# 2003
# 2003
# 2003          0.25
# 2003           0.5
# 2003          0.75
# 2003  0.6000000238
# 2003   0.525000006
#
# [20 rows x 691 columns]

# %%
import pandas as pd
import numpy as np
from eep153_tools.sheets import read_sheets

# Change 'Panama_Data' to key of your own sheet in Sheets, above
x = read_sheets(Panama_Data,sheet='Food Expenditures')
x.columns.name = 'j'

p = read_sheets(Panama_Data,sheet='Food Prices').set_index(['t','m'])
p.columns.name = 'j'
p = p.xs('2019-20',level='t')

d = read_sheets(Panama_Data,sheet="Household Characteristics")
d.columns.name = 'k'

# x may have duplicate columns
x = x.T.groupby('j').sum().T
x = x.replace(0,np.nan) # Replace zeros with missing

# Take logs of expenditures; call this y
y = np.log(x.set_index(['i','t','m']))

d.set_index(['i','t','m'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_250/2737981251.py in ?()
# ----> 9 import pandas as pd
#      10 import numpy as np
#      11 from eep153_tools.sheets import read_sheets
#      12
#
# /srv/conda/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6105                     if not found:
#    6106                         missing.append(col)
#    6107
#    6108         if missing:
# -> 6109             raise KeyError(f"None of {missing} are in the columns")
#    6110
#    6111         if inplace:
#    6112             frame = self
#
# KeyError: "None of ['t', 'm'] are in the columns"

# %%
d.head()

# %%
y.head()
