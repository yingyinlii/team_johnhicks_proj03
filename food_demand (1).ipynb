# %% [markdown]
# ## EEP153 Project 3 - Team John Hicks

# %% [markdown]
# Team members: Stone Yan, Angela Chen, Yingyin Li, Tia Pappas, Daniela Salinas, Lyuheng(Kasper) Zheng

# %% [markdown]
# #### Our Topic and Population of Interest:
#
# We are interested in the population of Panama. Our topic is about understanding diets in Panama, characterizing the relationship between people’s food choices, budget and prices.
#
# #### Our Goals:
#
# 1. Analyze Panama households' food choices and expenditures to assess their diets' nutritional content and adequacy.
# <br>
# 2. Estimate food demand among Panama, considering household needs and economic factors, and to analyze how changes in expenditure and food prices influence dietary choices.
# <br>
# 3. Conduct counterfactual experiments to assess how hypothetical economic scenarios, such as changes in food expenditure, prices, shortages, and income, could affect Panama's nutrition.

# %% [markdown]
# ### (A) Choice of Population & Supporting Data

# %% [markdown]
# #### Data Frame Set Up

# %% [markdown]
# Our choice of population is Panama. We first installed our prerequisites.

# %%
# !pip install -r requirements.txt 
# !pip install CFEDemands --upgrade --pre -q
# !pip install eep153_tools --upgrade -q
# Out:
# Requirement already satisfied: CFEDemands>=0.6 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: ConsumerDemands in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.4.2.dev0)
# Requirement already satisfied: matplotlib>=3.3.4 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (3.7.3)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (2.2.1)
# Requirement already satisfied: plotly>=5.1.0 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (5.19.0)
# Requirement already satisfied: eep153_tools>=0.11 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.12.4)
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.5.2)
# Requirement already satisfied: ray>=2.0.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (2.10.0)
# Requirement already satisfied: pytest>=7.1.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (7.4.4)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (1.10.0)
# Requirement already satisfied: xarray>=0.20.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (2024.3.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (0.13.5)
# Requirement already satisfied: joblib>=1.1.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: dvc>=2.18.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.6->-r requirements.txt (line 5)) (3.49.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (4.50.0)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (8.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (24.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (6.4.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.3.4->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.3.5->-r requirements.txt (line 20)) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from plotly>=5.1.0->-r requirements.txt (line 23)) (8.2.3)
# Requirement already satisfied: flufl.lock<8,>=5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (7.1.1)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: scmrepo<4,>=3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.3.1)
# Requirement already satisfied: configobj>=5.0.6 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.0.8)
# Requirement already satisfied: requests>=2.22 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: dvc-http>=2.29.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.32.0)
# Requirement already satisfied: gto<2,>=1.6.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: distro>=1.3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: networkx>=2.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: hydra-core>=1.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: dulwich in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.21.7)
# Requirement already satisfied: attrs>=22.2.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.1.6)
# Requirement already satisfied: dvc-objects in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: colorama>=0.3.9 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.17.40)
# Requirement already satisfied: kombu in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.3.6)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.65.0)
# Requirement already satisfied: fsspec in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2024.3.1)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.0.post1)
# Requirement already satisfied: pathspec>=0.10.3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: tomlkit>=0.11.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.12.4)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: rich>=12 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (13.7.1)
# Requirement already satisfied: omegaconf in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: pygtrie>=2.3.2 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: grandalf<1,>=0.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.8)
# Requirement already satisfied: psutil>=5.8 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.9.8)
# Requirement already satisfied: voluptuous>=0.11.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.14.2)
# Requirement already satisfied: dvc-data<3.16,>=3.15 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.15.1)
# Requirement already satisfied: celery in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.3.6)
# Requirement already satisfied: shtab<2,>=1.3.4 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: pydot>=1.2.4 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: tabulate>=0.8.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: shortuuid>=0.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.0.13)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.0.8)
# Requirement already satisfied: funcy>=1.14 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.0)
# Requirement already satisfied: dvc-studio-client<1,>=0.20 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.4->-r requirements.txt (line 10)) (3.17.0)
# Requirement already satisfied: iniconfig in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.25.3)
# Requirement already satisfied: aiosignal in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: frozenlist in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.0.8)
# Requirement already satisfied: jsonschema in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.21.1)
# Requirement already satisfied: filelock in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.13.3)
# Requirement already satisfied: pyyaml in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: click>=7.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: patsy>=0.5.2 in /srv/conda/lib/python3.9/site-packages (from statsmodels>=0.13.2->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: diskcache>=5.2.1 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: dictdiffer>=0.8.1 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /srv/conda/lib/python3.9/site-packages (from dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.8.3)
# Requirement already satisfied: billiard<5.0,>=4.2.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: click-repl>=0.2.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: atpublic>=2.3 in /srv/conda/lib/python3.9/site-packages (from flufl.lock<8,>=5->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: entrypoints in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.9.2)
# Requirement already satisfied: typer>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: semver>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /srv/conda/lib/python3.9/site-packages (from hydra-core>=1.1->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: appdirs in /srv/conda/lib/python3.9/site-packages (from iterative-telemetry>=0.0.7->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: typing-extensions in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.26.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.17.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /srv/conda/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.14.2)
# Requirement already satisfied: pygit2>=1.14.0 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: gitpython>3 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: setuptools in /srv/conda/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (59.8.0)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.34.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: aiohttp in /srv/conda/lib/python3.9/site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.9.3)
# Requirement already satisfied: cryptography>=39.0 in /srv/conda/lib/python3.9/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (39.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /srv/conda/lib/python3.9/site-packages (from click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.0.42)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /srv/conda/lib/python3.9/site-packages (from gitpython>3->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: cffi>=1.16.0 in /srv/conda/lib/python3.9/site-packages (from pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: orjson in /srv/conda/lib/python3.9/site-packages (from sqltrie<1,>=0.11.0->dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (1.9.4)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi>=1.16.0->pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /srv/conda/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: wcwidth in /srv/conda/lib/python3.9/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands>=0.6->-r requirements.txt (line 5)) (0.2.13)

# %% [markdown]
# In the following we will be estimating Constant Frisch Elasticity (CFE) demand systems for our selected population - Panama. We first imported the data we need from the Google Sheet, including food expenditures, food prices, household characteristics, FCT and RDI.

# %%
InputFiles = {'Food Expenditures':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Food Expenditures'),
              'Food Prices':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Food Prices'),
              'Household Characteristics':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Household Characteristics'),
              'FCT':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','FCT'),
              'Copy of RDI':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Copy of RDI'),}

# %% [markdown]
# We then imported the packages that are needed.

# %%
import numpy as np
import pandas as pd
from eep153_tools.sheets import read_sheets
import cfe
from cfe.estimation import drop_columns_wo_covariance
from cfe import Regression

# %%
def get_clean_sheet(key,sheet=None):

    df = read_sheets(key,sheet=sheet)
    df.columns = [c.strip() for c in df.columns.tolist()]

    df = df.loc[:,~df.columns.duplicated(keep='first')]   

    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    df = df.loc[~df.index.duplicated(), :]

    return df

# %%
# Get food expenditures 
expenditures = get_clean_sheet(InputFiles['Food Expenditures'][0],
                    sheet=InputFiles['Food Expenditures'][1])

if 'm' not in expenditures.columns:
    expenditures['m'] = 1

expenditures = expenditures.set_index(['i','t','m'])
expenditures.columns.name = 'j'

expenditures = expenditures.apply(lambda x: pd.to_numeric(x,errors='coerce'))
expenditures = expenditures.replace(0,np.nan)

# %%
# Remove duplicated indexs in expenditures
expenditures = expenditures.loc[~expenditures.index.duplicated()]

# %%
# Get Household characteristics 
hh_characteristics = get_clean_sheet(InputFiles['Household Characteristics'][0],
                    sheet=InputFiles['Household Characteristics'][1])

if 'm' not in hh_characteristics.columns:
    hh_characteristics['m'] = 1

hh_characteristics = hh_characteristics.set_index(['i','t','m'])
hh_characteristics.columns.name = 'k'
#hh_characteristics.name = 'value'  

hh_characteristics = hh_characteristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# %%
# Check if there is duplicated indexes in household characteristics
hh_characteristics.index.is_unique
# Out:
# True

# %%
# Get food prices and call it p
url = 'https://docs.google.com/spreadsheets/d/1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw/edit#gid=2085637103'
p = read_sheets(url,sheet='Food Prices',nheaders=2)

p.columns.names = ['t','m']
p.groupby(level='j').mean()

#use tranpose to switch columns and rows as the original structure of the dataframe was not applicable to use.
p = p.transpose()
if 'm' not in p.columns:
    p['m']=1

p=p.apply(lambda x: pd.to_numeric(x,errors='coerce'))
p=p.replace(0,np.nan)

# %%
# Get FCT
fct = get_clean_sheet(InputFiles['FCT'][0],
                    sheet=InputFiles['FCT'][1])

fct = fct.set_index('j')
fct.columns.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# %%
# Get RDI
rdi = get_clean_sheet(InputFiles['Copy of RDI'][0],
                    sheet=InputFiles['Copy of RDI'][1])
rdi = rdi.set_index('n')
rdi.columns.name = 'k'

# %% [markdown]
# #### Show Organized Data Frame

# %% [markdown]
# 1. Show food expenditures dataframe.

# %%
expenditures.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui             6.0        NaN        0.5  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971003 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971005 1997 Chíriqui             3.7        NaN        NaN  NaN
#
# j                       Alimento Infantil  Apio  Arroz  Arvejas  Azúcar  \
# i        t    m
# 19971000 1997 Chíriqui                2.7   0.3   7.25      NaN     1.6
# 19971001 1997 Chíriqui                NaN   NaN   4.80      NaN     NaN
# 19971002 1997 Chíriqui                NaN   NaN   6.00      NaN     2.0
# 19971003 1997 Chíriqui                NaN   NaN    NaN      NaN     NaN
# 19971005 1997 Chíriqui                NaN   NaN    NaN      NaN     4.5
#
# j                       Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                    ...
# 19971000 1997 Chíriqui        NaN  ...                       8.0
# 19971001 1997 Chíriqui        1.4  ...                       1.5
# 19971002 1997 Chíriqui        3.6  ...                       NaN
# 19971003 1997 Chíriqui        NaN  ...                       NaN
# 19971005 1997 Chíriqui        1.5  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro  Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui            0.7          NaN     NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN     0.3             NaN
# 19971002 1997 Chíriqui            3.5          NaN     NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN     NaN             NaN
# 19971005 1997 Chíriqui            0.7          NaN     NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN        0.8
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   1.0        NaN
#
# j                       Zapallo / Chayote  Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN   0.4
# 19971001 1997 Chíriqui                NaN   NaN
# 19971002 1997 Chíriqui                2.0   NaN
# 19971003 1997 Chíriqui                NaN   NaN
# 19971005 1997 Chíriqui                NaN   NaN
#
# [5 rows x 84 columns]

# %% [markdown]
# 2. Show household characteristics dataframe.

# %%
hh_characteristics.head()
# Out:
# k                            women  boys  men  girls  Males 00-03  \
# i       t    m
# 1997125 1997 Herrera             1     1    1      0            0
# 1997160 1997 Herrera             2     0    1      0            0
# 1997170 1997 Bocas Del Toro      1     3    1      4            1
# 1997177 1997 Bocas Del Toro      4     9    1      5            2
# 1997178 1997 Bocas Del Toro      2     1    2      2            0
#
# k                            Females 00-03  Males 04-08  Females 04-08  \
# i       t    m
# 1997125 1997 Herrera                     0            0              0
# 1997160 1997 Herrera                     0            0              0
# 1997170 1997 Bocas Del Toro              2            1              0
# 1997177 1997 Bocas Del Toro              1            4              1
# 1997178 1997 Bocas Del Toro              0            0              1
#
# k                            Males 09-13  Females 09-13  Males 14-18  \
# i       t    m
# 1997125 1997 Herrera                   1              0            0
# 1997160 1997 Herrera                   0              0            0
# 1997170 1997 Bocas Del Toro            0              1            1
# 1997177 1997 Bocas Del Toro            1              3            2
# 1997178 1997 Bocas Del Toro            1              0            0
#
# k                            Females 14-18  Males 19-30  Females 19-30  \
# i       t    m
# 1997125 1997 Herrera                     0            0              0
# 1997160 1997 Herrera                     0            0              0
# 1997170 1997 Bocas Del Toro              1            0              0
# 1997177 1997 Bocas Del Toro              0            0              2
# 1997178 1997 Bocas Del Toro              1            2              0
#
# k                            Males 31-50  Females 31-50  Males 51-99  \
# i       t    m
# 1997125 1997 Herrera                   0              1            1
# 1997160 1997 Herrera                   0              1            1
# 1997170 1997 Bocas Del Toro            0              1            1
# 1997177 1997 Bocas Del Toro            0              2            1
# 1997178 1997 Bocas Del Toro            0              1            0
#
# k                            Females 51-99  log HSize
# i       t    m
# 1997125 1997 Herrera                     0   1.098612
# 1997160 1997 Herrera                     1   1.098612
# 1997170 1997 Bocas Del Toro              0   2.197225
# 1997177 1997 Bocas Del Toro              0   2.944439
# 1997178 1997 Bocas Del Toro              1   1.945910

# %% [markdown]
# 3. Show food prices dataframe.

# %%
p.head()
# Out:
# j                   Aceite Vegetal                                            \
# u                       1/2 gallon  None bottle    can gallon gram large bay
# t    m
# 1997 Bocas Del Toro          3.225   NaN   1.20  2.975   6.70  NaN     1.500
#      Chíriqui                3.250  0.10   1.35    NaN   5.95  NaN     1.350
#      Coclé                   2.990  0.10   1.30    NaN   5.90  NaN     1.375
#      Colón                   3.250  0.10   1.34    NaN   5.75  NaN       NaN
#      Darién                  3.200  0.25   1.40    NaN   4.85  NaN     1.525
#
# j                                                ... Zapallo / Chayote  \
# u                   liter medium bar milliliter  ...              unit
# t    m                                           ...
# 1997 Bocas Del Toro   NaN      1.050        NaN  ...              0.10
#      Chíriqui         NaN      1.325        NaN  ...              0.10
#      Coclé            NaN      1.275        NaN  ...              0.15
#      Colón            NaN      0.850        NaN  ...              0.25
#      Darién           NaN      1.400        NaN  ...               NaN
#
# j                                    Ñame                                 \
# u                       value bag or sack gram ounce package pound  unit
# t    m
# 1997 Bocas Del Toro       NaN         3.6  NaN   NaN     NaN  0.40   NaN
#      Chíriqui        0.084416         NaN  NaN   NaN     NaN  0.40  0.15
#      Coclé           0.201299         NaN  NaN   NaN     NaN  0.50  0.50
#      Colón           0.045455         NaN  NaN   NaN     NaN  0.40  0.60
#      Darién               NaN         NaN  NaN   NaN     NaN  0.15   NaN
#
# j                              m
# u                       value
# t    m
# 1997 Bocas Del Toro       NaN  1
#      Chíriqui        0.038961  1
#      Coclé                NaN  1
#      Colón           0.064935  1
#      Darién               NaN  1
#
# [5 rows x 691 columns]

# %% [markdown]
# 4. Show FCT dataframe.

# %%
fct.head()
# Out:
# n                   Agua  Energía  Proteina  Grasa Total  Carbo-hidratos  \
# j
# Aceite Vegetal      0.00      884      0.00       100.00            0.00
# Aguacates          73.23      160      2.00        14.66            8.53
# Ahí Verde          93.89       20      0.86         0.17            3.64
# Ajo                63.80      134      5.30         0.20           29.30
# Alimento Infantil   3.00      510     12.50        27.00           54.30
#
# n                  Fibra Diet. total  Ceniza  Calcio  Fosforo  Hierro  ...  \
# j                                                                      ...
# Aceite Vegetal                   0.0    0.00       0        0    0.00  ...
# Aguacates                        6.7    1.58      12       52    0.55  ...
# Ahí Verde                        1.7    0.43      10       20    0.34  ...
# Ajo                              0.0    1.40      38      134    1.40  ...
# Alimento Infantil                0.0    3.20     530      420    9.00  ...
#
# n                  Colesterol  Potasio  Sodio  Zinc  Magnesio  Vit. B6  \
# j
# Aceite Vegetal              0        0      0  0.00         0     0.00
# Aguacates                   0      485      7  0.64        29     0.26
# Ahí Verde                   0      175      3  0.13        10     0.22
# Ajo                         0      529     19  1.00         0     0.00
# Alimento Infantil           0      600    180  6.00        55     0.30
#
# n                  Vit. B12  Ac. Fólico  Folato Equiv. FD  Fracción Comestible
# j
# Aceite Vegetal          0.0           0                 0                 1.00
# Aguacates               0.0           0                81                 0.74
# Ahí Verde               0.0           0                11                 0.82
# Ajo                     0.0           3                 0                 0.94
# Alimento Infantil       1.5          80               136                 1.00
#
# [5 rows x 28 columns]

# %% [markdown]
# 5. Show RDI dataframe.

# %%
rdi.head()
# Out:
# k        F 00-03  M 00-03  F 04-08  M 04-08  F 09-13  M 09-13  F 14-18  \
# n
# Energy    1000.0   1000.0   1200.0   1400.0   1600.0   1800.0   1800.0
# Protein     13.0     13.0     19.0     19.0     34.0     34.0     46.0
# Fiber       14.0     14.0     16.8     19.6     22.4     25.2     25.2
# Folate     150.0    150.0    200.0    200.0    300.0    300.0    400.0
# Calcium    700.0    700.0   1000.0   1000.0   1300.0   1300.0   1300.0
#
# k        M 14-18  F 19-30  M 19-30  F 31-50  M 31-50   F 51+   M 51+
# n
# Energy    2200.0   2000.0   2400.0   1800.0   2200.0  1600.0  2000.0
# Protein     52.0     46.0     56.0     46.0     56.0    46.0    56.0
# Fiber       30.8     28.0     33.6     25.2     30.8    22.4    28.0
# Folate     400.0    400.0    400.0    400.0    400.0   400.0   400.0
# Calcium   1300.0   1000.0   1000.0   1000.0   1000.0  1200.0  1000.0

# %% [markdown]
# ### (A) Estimate demand system

# %% [markdown]
#  Let $y_{i}^j$ be log household expenditure on food item $j$ from household $i$ of Panama. Our estimation regression takes the following form:
#  $$
#       y^j_{i} = A^j(p) + \gamma_j'd_i + \beta_j w_i + \zeta^j_i.
# $$

# %% [markdown]
# The formula above models the log household expenditure as a function of :<br>
#
# $A^j(p)$: A price index for food $j$, capturing how the pricing of good $j$ affects expenditure on food $j$;
# <br>
# $\gamma_j'd_i$: A household characterics demonstrating how demographics affects expenditure on food $j$; $\gamma_j$ is its coefficient.
# <br>
# $\beta_j w_i$: This term captures how the household's overall wealth affects its expenditure on food $j$; $\beta_j$ is its coefficent.
# <br>
# $\zeta^j_i$: This term captures other unobserved effect that influence food expenditure.

# %%
# log_expenditures represents the logarithm of food expenditures.
log_expenditures = np.log(expenditures)

log_expenditures.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui        1.791759        NaN  -0.693147  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui        1.252763        NaN        NaN  NaN
# 19971003 1997 Chíriqui        1.252763        NaN        NaN  NaN
# 19971005 1997 Chíriqui        1.308333        NaN        NaN  NaN
#
# j                       Alimento Infantil      Apio     Arroz  Arvejas  \
# i        t    m
# 19971000 1997 Chíriqui           0.993252 -1.203973  1.981001      NaN
# 19971001 1997 Chíriqui                NaN       NaN  1.568616      NaN
# 19971002 1997 Chíriqui                NaN       NaN  1.791759      NaN
# 19971003 1997 Chíriqui                NaN       NaN       NaN      NaN
# 19971005 1997 Chíriqui                NaN       NaN       NaN      NaN
#
# j                         Azúcar  Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                              ...
# 19971000 1997 Chíriqui  0.470004        NaN  ...                  2.079442
# 19971001 1997 Chíriqui       NaN   0.336472  ...                  0.405465
# 19971002 1997 Chíriqui  0.693147   1.280934  ...                       NaN
# 19971003 1997 Chíriqui       NaN        NaN  ...                       NaN
# 19971005 1997 Chíriqui  1.504077   0.405465  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro    Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui      -0.356675          NaN       NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN -1.203973             NaN
# 19971002 1997 Chíriqui       1.252763          NaN       NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN       NaN             NaN
# 19971005 1997 Chíriqui      -0.356675          NaN       NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN  -0.223144
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   0.0        NaN
#
# j                       Zapallo / Chayote      Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN -0.916291
# 19971001 1997 Chíriqui                NaN       NaN
# 19971002 1997 Chíriqui           0.693147       NaN
# 19971003 1997 Chíriqui                NaN       NaN
# 19971005 1997 Chíriqui                NaN       NaN
#
# [5 rows x 84 columns]

# %%
# use is the intersection of indexs between log_expenditures and household characteristics.
use = log_expenditures.index.intersection(hh_characteristics.index)

log_expenditures = log_expenditures.loc[use,:]
hh_characteristics = hh_characteristics.loc[use,:]

# %%
# stack log expenditures and household characteristics
log_expenditures = log_expenditures.stack()
hh_characteristics = hh_characteristics.stack()

# Check that indices are in right places
assert log_expenditures.index.names == ['i','t','m','j']
assert hh_characteristics.index.names == ['i','t','m','k']

# %% [markdown]
# #### 1. Basic Estimation Using Regression

# %%
# Set up regression
result = Regression(y = log_expenditures,d = hh_characteristics)

# %%
# Get regression results
result.predicted_expenditures()
# Out:
# i         t     m                    j
# 20081     2008  Bocas Del Toro       Aceite Vegetal               5.326744
#                                      Ajo                          0.686368
#                                      Arroz                        7.549828
#                                      Azúcar                       2.972885
#                                      Café Y Té                    2.636834
#                                                                     ...
# 20087040  2008  Comarca Ngobe Bugle  Queso (Blanco Y Amarillo)    1.720973
#                                      Raspados Y Duros             1.391364
#                                      Sal                          0.630284
#                                      Sardina Y Atún               3.746857
#                                      Sodas, Refrescos Y Jugos     2.617251
# Length: 417378, dtype: float64

# %%
# Compare log food expenditures and actual expenditures by using a graph  
# %matplotlib widget
df = pd.DataFrame({'y':log_expenditures,'yhat':result.get_predicted_log_expenditures()})
scatter = df.plot.scatter(x='yhat',y='y',color='DarkBlue',alpha=.3)

scatter.set_title('Actual vs. Predicted Log Food Expenditures')
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted Log Food Expenditures')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### 2. Analyze Income Elasticity

# %%
#get the value of beta - As shown above, beta captures how the household's overall wealth affects its expenditures on food. 
result.get_beta().sort_values()
# Out:
# j
# Arroz                           0.192973
# Sal                             0.201887
# Porotos                         0.280774
# Lentejas                        0.285185
# Harina De Trigo                 0.300230
# Azúcar                          0.324121
# Café Y Té                       0.334031
# Ajo                             0.400300
# Aceite Vegetal                  0.439102
# Huevos De Gallina               0.448744
# Sardina Y Atún                  0.465135
# Pastas Alimenticias             0.474768
# Cebolla                         0.487377
# Carnes De Puerco                0.554748
# Pastas De Tomate                0.562173
# Lecha Evaporada                 0.562755
# Pescados                        0.603913
# Pollo O Gallina                 0.610001
# Queso (Blanco Y Amarillo)       0.681416
# Raspados Y Duros                0.712380
# Cereales Y Cremas               0.734479
# Pan De Sal Y Pan De Dulce       0.746018
# Embutidos                       0.766246
# Galletas / Pasteles Y Dulces    0.777834
# Sodas, Refrescos Y Jugos        0.927474
# Cigarrillo Y Tabaco             1.018577
# Name: beta, dtype: float64

# %% [markdown]
# The $\beta$ values above show us how household's overal wealth affect food expenditures. A smaller $\beta$ value is associated with a more inelastic product and it is more stable. For example, arroz (rice) is a necessity good for Panama households and gaining more wealth does not heavily influence spending on rice.

# %%
# Graph beta
result.graph_beta()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# get the value of gamma - As shown above, gamma captures how household characteristics affects its expenditures on food. 
result.gamma
# Out:
# k                                women      boys       men     girls  \
# j
# Aceite Vegetal               -0.218800 -0.024408 -0.030141 -0.230595
# Ajo                           0.122637 -0.025084 -0.011583  0.110984
# Arroz                        -0.495017 -0.142311 -0.126351 -0.433308
# Azúcar                       -0.265898 -0.326834 -0.375346 -0.222052
# Café Y Té                     0.107552  0.037827  0.071886  0.093084
# Carnes De Puerco              0.045177 -0.301312 -0.294398 -0.033335
# Cebolla                       0.517222 -0.781819 -0.770107  0.515412
# Cereales Y Cremas             0.605760 -0.101034 -0.083822  0.578808
# Cigarrillo Y Tabaco          -0.101663  0.086289 -0.074436  0.141626
# Embutidos                    -0.010568 -0.056603 -0.026221 -0.011897
# Galletas / Pasteles Y Dulces  0.397448  0.004136 -0.151644  0.440199
# Harina De Trigo              -0.065359  0.116589  0.027788 -0.092045
# Huevos De Gallina             0.312620  0.652181  0.627059  0.284722
# Lecha Evaporada               0.635685 -0.068516 -0.018879  0.700987
# Lentejas                      0.180110 -0.090725 -0.057532  0.192931
# Pan De Sal Y Pan De Dulce     0.930191  1.951816  1.879863  0.851370
# Pastas Alimenticias          -0.223868 -0.180833 -0.209174 -0.250905
# Pastas De Tomate              0.474168 -0.316775 -0.338268  0.392776
# Pescados                     -0.370275 -0.337657 -0.254599 -0.436552
# Pollo O Gallina               0.647154 -0.397586 -0.430456  0.642322
# Porotos                       0.254177 -0.045206 -0.024987  0.270279
# Queso (Blanco Y Amarillo)     0.895912  0.585071  0.537501  0.853321
# Raspados Y Duros             -0.034549 -0.055351 -0.014580  0.011608
# Sal                          -0.036866  0.395064  0.385574 -0.008333
# Sardina Y Atún                0.095095  0.017292  0.040795  0.075529
# Sodas, Refrescos Y Jugos     -0.308647  2.216828  2.167608 -0.389691
#
# k                             Males 00-03  Females 00-03  Males 04-08  \
# j
# Aceite Vegetal                  -0.084642       0.109983    -0.038135
# Ajo                             -0.035544      -0.177410    -0.052475
# Arroz                            0.067605       0.343353     0.085655
# Azúcar                           0.360380       0.264523     0.367596
# Café Y Té                       -0.055893      -0.090284    -0.026736
# Carnes De Puerco                 0.249685      -0.047868     0.246697
# Cebolla                          0.723260      -0.591330     0.733311
# Cereales Y Cremas                0.011618      -0.702876     0.032771
# Cigarrillo Y Tabaco             -0.240744      -0.251202    -0.134721
# Embutidos                       -0.095048      -0.143369    -0.024817
# Galletas / Pasteles Y Dulces    -0.155111      -0.558963    -0.054663
# Harina De Trigo                 -0.058579       0.117643    -0.020683
# Huevos De Gallina               -0.693687      -0.362306    -0.663343
# Lecha Evaporada                  0.032291      -0.754897    -0.019588
# Lentejas                         0.112481      -0.163829     0.135435
# Pan De Sal Y Pan De Dulce       -2.108399      -1.009674    -2.023417
# Pastas Alimenticias              0.179706       0.230601     0.193244
# Pastas De Tomate                 0.186322      -0.509572     0.233723
# Pescados                         0.265749       0.390666     0.293661
# Pollo O Gallina                  0.276149      -0.763890     0.297135
# Porotos                          0.079627      -0.239489     0.090792
# Queso (Blanco Y Amarillo)       -0.742348      -1.007077    -0.659149
# Raspados Y Duros                -0.081955      -0.111898     0.033941
# Sal                             -0.368690       0.005395    -0.354940
# Sardina Y Atún                  -0.026297      -0.099903    -0.013734
# Sodas, Refrescos Y Jugos        -2.377692       0.281176    -2.289664
#
# k                             Females 04-08  Males 09-13  Females 09-13  \
# j
# Aceite Vegetal                     0.150058    -0.036179       0.178815
# Ajo                               -0.173803    -0.014226      -0.143469
# Arroz                              0.377398     0.155812       0.444869
# Azúcar                             0.262885     0.384716       0.285495
# Café Y Té                         -0.094427    -0.004059      -0.087892
# Carnes De Puerco                  -0.038958     0.251480       0.014306
# Cebolla                           -0.569407     0.740026      -0.541136
# Cereales Y Cremas                 -0.651868    -0.024667      -0.739802
# Cigarrillo Y Tabaco               -0.336134    -0.044710      -0.189543
# Embutidos                         -0.046459    -0.001692      -0.076045
# Galletas / Pasteles Y Dulces      -0.496932    -0.085740      -0.509623
# Harina De Trigo                    0.140836    -0.019426       0.213237
# Huevos De Gallina                 -0.311619    -0.682536      -0.292103
# Lecha Evaporada                   -0.783220    -0.025569      -0.788646
# Lentejas                          -0.174619     0.181507      -0.118542
# Pan De Sal Y Pan De Dulce         -0.940445    -1.995386      -0.932439
# Pastas Alimenticias                0.266520     0.207448       0.254763
# Pastas De Tomate                  -0.456114     0.227719      -0.508202
# Pescados                           0.403563     0.314353       0.387319
# Pollo O Gallina                   -0.713466     0.329264      -0.701534
# Porotos                           -0.232314     0.125007      -0.196102
# Queso (Blanco Y Amarillo)         -0.953098    -0.633589      -0.959408
# Raspados Y Duros                  -0.122127     0.029241      -0.101257
# Sal                                0.056942    -0.319745       0.080273
# Sardina Y Atún                    -0.064608    -0.012714      -0.056191
# Sodas, Refrescos Y Jugos           0.320181    -2.308194       0.264160
#
# k                             Males 14-18  Females 14-18  Males 19-30  \
# j
# Aceite Vegetal                  -0.015462       0.170152     0.014687
# Ajo                             -0.003958      -0.130994     0.000739
# Arroz                            0.209597       0.427199     0.180513
# Azúcar                           0.431125       0.277118     0.412952
# Café Y Té                       -0.021151      -0.067830    -0.015116
# Carnes De Puerco                 0.309919      -0.005435     0.319415
# Cebolla                          0.770595      -0.541348     0.780842
# Cereales Y Cremas               -0.062239      -0.738672    -0.027777
# Cigarrillo Y Tabaco             -0.048370      -0.035542     0.159658
# Embutidos                       -0.013134      -0.039069    -0.009369
# Galletas / Pasteles Y Dulces    -0.104942      -0.511241     0.068254
# Harina De Trigo                  0.061754       0.187320     0.051969
# Huevos De Gallina               -0.652994      -0.276351    -0.636434
# Lecha Evaporada                  0.013542      -0.802973    -0.075886
# Lentejas                         0.171218      -0.114854     0.163099
# Pan De Sal Y Pan De Dulce       -1.955207      -0.920771    -1.909766
# Pastas Alimenticias              0.233724       0.315537     0.251907
# Pastas De Tomate                 0.249844      -0.459461     0.329285
# Pescados                         0.311677       0.380376     0.272774
# Pollo O Gallina                  0.382658      -0.660453     0.425760
# Porotos                          0.119680      -0.189765     0.122365
# Queso (Blanco Y Amarillo)       -0.642771      -0.935572    -0.588866
# Raspados Y Duros                -0.009743      -0.035912    -0.047881
# Sal                             -0.285722       0.068540    -0.307605
# Sardina Y Atún                   0.018197      -0.057432     0.014682
# Sodas, Refrescos Y Jugos        -2.298380       0.288212    -2.199661
#
# k                             Females 19-30  Males 31-50  Females 31-50  \
# j
# Aceite Vegetal                     0.236073     0.043749       0.293211
# Ajo                               -0.109235     0.023851      -0.065176
# Arroz                              0.438819     0.214572       0.402831
# Azúcar                             0.273946     0.442871       0.285191
# Café Y Té                         -0.079083     0.077907       0.003700
# Carnes De Puerco                  -0.012839     0.376477       0.042634
# Cebolla                           -0.494382     0.827029      -0.464914
# Cereales Y Cremas                 -0.593578    -0.027540      -0.471550
# Cigarrillo Y Tabaco                0.292745     0.164842       0.411516
# Embutidos                          0.070749     0.044068       0.172816
# Galletas / Pasteles Y Dulces      -0.374285     0.105185      -0.279105
# Harina De Trigo                    0.103200     0.037683       0.066425
# Huevos De Gallina                 -0.288928    -0.603742      -0.259485
# Lecha Evaporada                   -0.677257    -0.024768      -0.619299
# Lentejas                          -0.163602     0.156539      -0.196614
# Pan De Sal Y Pan De Dulce         -0.879654    -1.878448      -0.755763
# Pastas Alimenticias                0.260944     0.258638       0.295869
# Pastas De Tomate                  -0.449383     0.343348      -0.403584
# Pescados                           0.421797     0.329823       0.552222
# Pollo O Gallina                   -0.597202     0.470702      -0.532534
# Porotos                           -0.224963     0.144134      -0.255865
# Queso (Blanco Y Amarillo)         -0.860188    -0.563832      -0.772354
# Raspados Y Duros                   0.109275    -0.026730       0.148552
# Sal                                0.049931    -0.287304       0.030172
# Sardina Y Atún                    -0.062764     0.034811      -0.048438
# Sodas, Refrescos Y Jugos           0.362365    -2.186962       0.474710
#
# k                             Males 51-99  Females 51-99  log HSize  Constant
# j
# Aceite Vegetal                   0.061494       0.230366   0.338633  0.974171
# Ajo                              0.044902      -0.078070   0.190007 -0.701542
# Arroz                            0.216298       0.430696   0.606707  1.794254
# Azúcar                           0.513693       0.324265   0.320733  0.412778
# Café Y Té                        0.154792       0.055753  -0.014526  0.498742
# Carnes De Puerco                 0.424761      -0.049411   0.216704  1.506556
# Cebolla                          0.859738      -0.499388   0.246953 -0.127551
# Cereales Y Cremas               -0.086985      -0.680897   0.520374  0.604486
# Cigarrillo Y Tabaco              0.155957       0.148354  -0.147226  0.929062
# Embutidos                        0.017223       0.039137   0.406616  0.903679
# Galletas / Pasteles Y Dulces     0.079521      -0.363482   0.369629  0.186533
# Harina De Trigo                  0.091647       0.083411   0.003653 -0.213679
# Huevos De Gallina               -0.577954      -0.291971   0.283553  0.364942
# Lecha Evaporada                  0.012623      -0.655143   0.468667  0.652743
# Lentejas                         0.209557      -0.178410   0.031320  0.063322
# Pan De Sal Y Pan De Dulce       -1.899246      -0.827737   0.590620  0.948243
# Pastas Alimenticias              0.278605       0.270287   0.119667  0.160371
# Pastas De Tomate                 0.285728      -0.519533   0.399467  0.400316
# Pescados                         0.400859       0.454085   0.158577  1.132902
# Pollo O Gallina                  0.490697      -0.573076   0.453715  1.912284
# Porotos                          0.170249      -0.247143   0.019374  0.317587
# Queso (Blanco Y Amarillo)       -0.557218      -0.867931   0.410502  0.779795
# Raspados Y Duros                 0.033200       0.090438   0.414328  0.055572
# Sal                             -0.221154       0.098828   0.074649 -0.954633
# Sardina Y Atún                   0.043178      -0.084073   0.071954  0.570696
# Sodas, Refrescos Y Jugos        -2.211782       0.296171   0.401156  0.913872

# %% [markdown]
# The $\gamma$ value tables gives us a glimpse of how different household characteristics affect food expenditures on a certain product. For example, an additional woman in Pananma household is associated with a reduction of 0.22 log expenditures of Panama currency spent on Aceite Vegetal (Vegetable Oil).

# %%
# Save result
result.to_pickle('estimates.pickle')

result = cfe.regression.read_pickle('estimates.pickle')

# %%
from cfe import regression as rgsn
import numpy as np

# Load a regression model from a pickle file that was named 'estimates.pickle' earlier.
r = rgsn.read_pickle('estimates.pickle')

# Use the loaded model to predict expenditures based on the model's estimates.
xhat = r.predicted_expenditures()

# Implied relative prices
p = np.exp(r.get_Ar())

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

use = 'Arroz'  # Put the food item that we want demand curve for here. 
               # 'Arroz' is translated to 'rice' in English. 

# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p.groupby(level='j').mean()

def my_prices(p0,p=pbar,j='Arroz'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    """
    p = p.copy()
    p.loc[j] = p0
    return p
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Demand for Rice for household at median budget
plt.plot([r.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='Median')

# Demand for Rice for household at 25% percentile
plt.plot([r.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='25th Percentile')

# Demand for Rice for household at 75% percentile
plt.plot([r.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='75th Percentile')

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of Rice Demanded (lb)")
plt.legend()

plt.show()

# %%
# demand curve for chicken

import matplotlib.pyplot as plt
# %matplotlib notebook

use = 'Pollo O Gallina'  # Put the food item that we want demand curve for here. 
               # 'Pollo O Gallina' is translated to 'chicken' in English. 

# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p.groupby(level='j').mean()

def my_prices(p0,p=pbar,j='Pollo O Gallina'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %%
# demand curve for chicken

import matplotlib.pyplot as plt
# %matplotlib inline

# Demand for chicken for household at median budget
plt.plot([r.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='Median')

# Demand for chicken for household at 25% percentile
plt.plot([r.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='25th Percentile')

# Demand for chicken for household at 75% percentile
plt.plot([r.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='75th Percentile')

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of Chicken Demanded (lbs)")
plt.legend()
plt.show()

# %%
# demand curve for eggs

import matplotlib.pyplot as plt
# %matplotlib notebook

use = 'Huevos De Gallina'  # Put the food item that we want demand curve for here. 
               # 'huevos' is translated to 'eggs' in English. 

# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p.groupby(level='j').mean()

def my_prices(p0,p=pbar,j='Huevos De Gallina'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Demand for eggs for household at median budget
plt.plot([r.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='Median')

# Demand for eggs for household at 25% percentile
plt.plot([r.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='25th Percentile')

# Demand for eggs for household at 75% percentile
plt.plot([r.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='75th Percentile')

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of Eggs Demanded (lbs)")
plt.legend()

# %%
# demand for Galletas / Pasteles Y Dulces
import matplotlib.pyplot as plt
# %matplotlib notebook

use = 'Galletas / Pasteles Y Dulces'  # Put the food item that we want demand curve for here. 
               # 'Galletas / Pasteles Y Dulces' is translated to 'desserts' in English. 

# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p.groupby(level='j').mean()

def my_prices(p0,p=pbar,j='Galletas / Pasteles Y Dulces'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Demand for Galletas / Pasteles Y Dulces for household at median budget
plt.plot([r.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='Median')

# Demand for Galletas / Pasteles Y Dulces for household at 25% percentile
plt.plot([r.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='25th Percentile')

# Demand for Galletas / Pasteles Y Dulces for household at 75% percentile
plt.plot([r.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale, label='75th Percentile')

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of Galletas / Pasteles Y Dulces Demanded (lbs)")
plt.legend()

# %%
# demand for Galletas / Pasteles Y Dulces
import matplotlib.pyplot as plt
# %matplotlib notebook

use = [['Arroz', 'Pollo O Gallina', 'Galletas / Pasteles Y Dulces', 'Aceite Vegetal', 
         'Cigarrillo Y Tabaco', 'Pescados', 'Café Y Té'] # Put the food item that we want demand curve for here. 
               # 'Galletas / Pasteles Y Dulces' is translated to 'desserts' in English. 

# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p.groupby(level='j').mean()

def my_prices(p0,p=pbar,j='Galletas / Pasteles Y Dulces'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    """
    p = p.copy()
    p.loc[j] = p0
    return p
    
import matplotlib.pyplot as plt
# %matplotlib inline

# Demand for Galletas / Pasteles Y Dulces for household at median budget
plt.plot([r.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)
plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of Food Demanded (lbs)")
# Out:
#   Cell In[36], line 10
#     scale = np.linspace(.5,2,20)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### (B) Nutritional Content of Different Food

# %%
# The FCT table shows the nutrients of each food item in our dataset. 
fct.head(10)
# Out:
# n                   Agua  Energía  Proteina  Grasa Total  Carbo-hidratos  \
# j
# Aceite Vegetal      0.00      884      0.00       100.00            0.00
# Aguacates          73.23      160      2.00        14.66            8.53
# Ahí Verde          93.89       20      0.86         0.17            3.64
# Ajo                63.80      134      5.30         0.20           29.30
# Alimento Infantil   3.00      510     12.50        27.00           54.30
# Apio               95.43       14      0.69         0.17            2.97
# Arroz              12.37      362      7.50         2.68           76.17
# Arvejas            11.27      341     24.55         1.16           60.37
# Azúcar              0.70      384      0.00         0.00           99.10
# Café Y Té          99.39        1      0.12         0.02            0.00
#
# n                  Fibra Diet. total  Ceniza  Calcio  Fosforo  Hierro  ...  \
# j                                                                      ...
# Aceite Vegetal                   0.0    0.00       0        0    0.00  ...
# Aguacates                        6.7    1.58      12       52    0.55  ...
# Ahí Verde                        1.7    0.43      10       20    0.34  ...
# Ajo                              0.0    1.40      38      134    1.40  ...
# Alimento Infantil                0.0    3.20     530      420    9.00  ...
# Apio                             1.6    0.75      40       24    0.20  ...
# Arroz                            3.4    1.27      33      264    1.80  ...
# Arvejas                         25.5    2.65      55      366    4.43  ...
# Azúcar                           0.0    0.20       5        1    0.10  ...
# Café Y Té                        0.0    0.35       2        3    0.01  ...
#
# n                  Colesterol  Potasio  Sodio  Zinc  Magnesio  Vit. B6  \
# j
# Aceite Vegetal              0        0      0  0.00         0     0.00
# Aguacates                   0      485      7  0.64        29     0.26
# Ahí Verde                   0      175      3  0.13        10     0.22
# Ajo                         0      529     19  1.00         0     0.00
# Alimento Infantil           0      600    180  6.00        55     0.30
# Apio                        0      260     80  0.13        11     0.07
# Arroz                       0      268      4  2.02       143     0.51
# Arvejas                     0      981     15  3.01       115     0.17
# Azúcar                      0        0      0  0.00         0     0.00
# Café Y Té                   0       49      2  0.02         3     0.00
#
# n                  Vit. B12  Ac. Fólico  Folato Equiv. FD  Fracción Comestible
# j
# Aceite Vegetal          0.0           0                 0                 1.00
# Aguacates               0.0           0                81                 0.74
# Ahí Verde               0.0           0                11                 0.82
# Ajo                     0.0           3                 0                 0.94
# Alimento Infantil       1.5          80               136                 1.00
# Apio                    0.0           0                36                 0.89
# Arroz                   0.0           0                20                 1.00
# Arvejas                 0.0           0               274                 1.00
# Azúcar                  0.0           0                 0                 1.00
# Café Y Té               0.0           0                 2                 1.00
#
# [10 rows x 28 columns]

# %%
# The following table shows the recommended daily intakes for different populations, across males and females of various ages.
rdi.head(10)
# Out:
# k             F 00-03  M 00-03  F 04-08  M 04-08  F 09-13  M 09-13  F 14-18  \
# n
# Energy         1000.0   1000.0   1200.0   1400.0   1600.0   1800.0   1800.0
# Protein          13.0     13.0     19.0     19.0     34.0     34.0     46.0
# Fiber            14.0     14.0     16.8     19.6     22.4     25.2     25.2
# Folate          150.0    150.0    200.0    200.0    300.0    300.0    400.0
# Calcium         700.0    700.0   1000.0   1000.0   1300.0   1300.0   1300.0
# Carbohydrate    130.0    130.0    130.0    130.0    130.0    130.0    130.0
# Iron              7.0      7.0     10.0     10.0      8.0      8.0     15.0
# Magnesium        80.0     80.0    130.0    130.0    240.0    240.0    360.0
# Niacin            6.0      6.0      8.0      8.0     12.0     12.0     14.0
# Phosphorus      460.0    460.0    500.0    500.0   1250.0   1250.0   1250.0
#
# k             M 14-18  F 19-30  M 19-30  F 31-50  M 31-50   F 51+   M 51+
# n
# Energy         2200.0   2000.0   2400.0   1800.0   2200.0  1600.0  2000.0
# Protein          52.0     46.0     56.0     46.0     56.0    46.0    56.0
# Fiber            30.8     28.0     33.6     25.2     30.8    22.4    28.0
# Folate          400.0    400.0    400.0    400.0    400.0   400.0   400.0
# Calcium        1300.0   1000.0   1000.0   1000.0   1000.0  1200.0  1000.0
# Carbohydrate    130.0    130.0    130.0    130.0    130.0   130.0   130.0
# Iron             11.0     18.0      8.0     18.0      8.0     8.0     8.0
# Magnesium       410.0    310.0    400.0    320.0    420.0   320.0   420.0
# Niacin           16.0     14.0     16.0     14.0     16.0    14.0    16.0
# Phosphorus     1250.0    700.0    700.0    700.0    700.0   700.0   700.0

# %% [markdown]
# ### (C) Counterfactual Experiments

# %% [markdown]
# In this section we look at different scenarios.

# %% [markdown]
# If everyone's food expenditure doubled (holding prices fixed), how would this affect nutrition in Panama?

# %%
expenditures.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui             6.0        NaN        0.5  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971003 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971005 1997 Chíriqui             3.7        NaN        NaN  NaN
#
# j                       Alimento Infantil  Apio  Arroz  Arvejas  Azúcar  \
# i        t    m
# 19971000 1997 Chíriqui                2.7   0.3   7.25      NaN     1.6
# 19971001 1997 Chíriqui                NaN   NaN   4.80      NaN     NaN
# 19971002 1997 Chíriqui                NaN   NaN   6.00      NaN     2.0
# 19971003 1997 Chíriqui                NaN   NaN    NaN      NaN     NaN
# 19971005 1997 Chíriqui                NaN   NaN    NaN      NaN     4.5
#
# j                       Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                    ...
# 19971000 1997 Chíriqui        NaN  ...                       8.0
# 19971001 1997 Chíriqui        1.4  ...                       1.5
# 19971002 1997 Chíriqui        3.6  ...                       NaN
# 19971003 1997 Chíriqui        NaN  ...                       NaN
# 19971005 1997 Chíriqui        1.5  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro  Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui            0.7          NaN     NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN     0.3             NaN
# 19971002 1997 Chíriqui            3.5          NaN     NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN     NaN             NaN
# 19971005 1997 Chíriqui            0.7          NaN     NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN        0.8
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   1.0        NaN
#
# j                       Zapallo / Chayote  Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN   0.4
# 19971001 1997 Chíriqui                NaN   NaN
# 19971002 1997 Chíriqui                2.0   NaN
# 19971003 1997 Chíriqui                NaN   NaN
# 19971005 1997 Chíriqui                NaN   NaN
#
# [5 rows x 84 columns]

# %%
double_exp = expenditures * 2
double_exp.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui            12.0        NaN        1.0  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui             7.0        NaN        NaN  NaN
# 19971003 1997 Chíriqui             7.0        NaN        NaN  NaN
# 19971005 1997 Chíriqui             7.4        NaN        NaN  NaN
#
# j                       Alimento Infantil  Apio  Arroz  Arvejas  Azúcar  \
# i        t    m
# 19971000 1997 Chíriqui                5.4   0.6   14.5      NaN     3.2
# 19971001 1997 Chíriqui                NaN   NaN    9.6      NaN     NaN
# 19971002 1997 Chíriqui                NaN   NaN   12.0      NaN     4.0
# 19971003 1997 Chíriqui                NaN   NaN    NaN      NaN     NaN
# 19971005 1997 Chíriqui                NaN   NaN    NaN      NaN     9.0
#
# j                       Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                    ...
# 19971000 1997 Chíriqui        NaN  ...                      16.0
# 19971001 1997 Chíriqui        2.8  ...                       3.0
# 19971002 1997 Chíriqui        7.2  ...                       NaN
# 19971003 1997 Chíriqui        NaN  ...                       NaN
# 19971005 1997 Chíriqui        3.0  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro  Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui            1.4          NaN     NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN     0.6             NaN
# 19971002 1997 Chíriqui            7.0          NaN     NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN     NaN             NaN
# 19971005 1997 Chíriqui            1.4          NaN     NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN        1.6
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   2.0        NaN
#
# j                       Zapallo / Chayote  Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN   0.8
# 19971001 1997 Chíriqui                NaN   NaN
# 19971002 1997 Chíriqui                4.0   NaN
# 19971003 1997 Chíriqui                NaN   NaN
# 19971005 1997 Chíriqui                NaN   NaN
#
# [5 rows x 84 columns]

# %%
double_result = cfe.Regression(y=np.log(double_exp.stack()), d=hh_characteristics)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

foods = ['Arroz', 'Pollo O Gallina', 'Galletas / Pasteles Y Dulces', 'Aceite Vegetal', 
         'Cigarrillo Y Tabaco', 'Pescados', 'Café Y Té']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'pink', 'yellow']  

# Assuming 'r', 'xbar', 'pbar' are defined in your context
X = np.linspace(xbar.quantile(0.001), xbar.quantile(0.99), 20)

for f, color in zip(foods, colors):
    ax.plot(X, [r.demands(x, pbar)[f] for x in X], color=color)
    
ax.legend(foods)
ax.set_xlabel('Budget ($)')
ax.set_ylabel('Estimated Demands (Quantities of [Food] Demanded)')
ax.set_title('Engel Curve for Foods')

plt.show()

# %%
fig,ax = plt.subplots()

ax.plot(scale*xref,[result.indirect_utility(s*xref,pbar) for s in scale])
ax.set_xlabel(f'Indirect Utility (Budget relative to base of {xref:.0f})')
ax.set_ylabel(f'Utility')
ax.set_title('Indirect Utility Function')
# Out:
# Text(0.5, 1.0, 'Indirect Utility Function')
