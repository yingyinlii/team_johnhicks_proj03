# %%
# !pip install -r requirements.txt 
# !pip install CFEDemands --upgrade --pre -q
# !pip install eep153_tools --upgrade -q
# !pip install python-gnupg
# Out:
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.9/site-packages (0.5.2)

# %%
InputFiles = {'Food Expenditures':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Food Expenditures'),
              'Food Prices':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Food Prices'),
              'Household Characteristics':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Household Characteristics'),
              'FCT':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','FCT'),
              'Copy of RDI':('1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw','Copy of RDI'),}

# %%
import numpy as np
import pandas as pd
from eep153_tools.sheets import read_sheets
import cfe
from cfe.estimation import drop_columns_wo_covariance
from cfe import Regression

# %%
def get_clean_sheet(key,sheet=None):

    df = read_sheets(key,sheet=sheet)
    df.columns = [c.strip() for c in df.columns.tolist()]

    df = df.loc[:,~df.columns.duplicated(keep='first')]   

    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    df = df.loc[~df.index.duplicated(), :]

    return df

# %%
# Get food expenditures 
expenditures = get_clean_sheet(InputFiles['Food Expenditures'][0],
                    sheet=InputFiles['Food Expenditures'][1])

if 'm' not in expenditures.columns:
    expenditures['m'] = 1

expenditures = expenditures.set_index(['i','t','m'])
expenditures.columns.name = 'j'

expenditures = expenditures.apply(lambda x: pd.to_numeric(x,errors='coerce'))
expenditures = expenditures.replace(0,np.nan)

# %%
expenditures = expenditures.loc[~expenditures.index.duplicated()]

# %%
# Get Household characteristics 
hh_characteristics = get_clean_sheet(InputFiles['Household Characteristics'][0],
                    sheet=InputFiles['Household Characteristics'][1])

if 'm' not in hh_characteristics.columns:
    hh_characteristics['m'] = 1

hh_characteristics = hh_characteristics.set_index(['i','t','m'])
hh_characteristics.columns.name = 'k'
#hh_characteristics.name = 'value'  

hh_characteristics = hh_characteristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# %%
hh_characteristics
# Out:
# k                                  women  boys  men  girls  Males 00-03  \
# i        t    m
# 1997125  1997 Herrera                  1     1    1      0            0
# 1997160  1997 Herrera                  2     0    1      0            0
# 1997170  1997 Bocas Del Toro           1     3    1      4            1
# 1997177  1997 Bocas Del Toro           4     9    1      5            2
# 1997178  1997 Bocas Del Toro           2     1    2      2            0
# ...                                  ...   ...  ...    ...          ...
# 20087041 2008 Comarca Ngobe Bugle      3     3    1      1            2
# 20087042 2008 Comarca Ngobe Bugle      1     3    1      3            2
# 20087043 2008 Comarca Ngobe Bugle      2     3    1      3            2
# 20087044 2008 Comarca Ngobe Bugle      2     1    2      3            1
# 20087045 2008 Comarca Ngobe Bugle      1     0    1      3            0
#
# k                                  Females 00-03  Males 04-08  Females 04-08  \
# i        t    m
# 1997125  1997 Herrera                          0            0              0
# 1997160  1997 Herrera                          0            0              0
# 1997170  1997 Bocas Del Toro                   2            1              0
# 1997177  1997 Bocas Del Toro                   1            4              1
# 1997178  1997 Bocas Del Toro                   0            0              1
# ...                                          ...          ...            ...
# 20087041 2008 Comarca Ngobe Bugle              1            1              0
# 20087042 2008 Comarca Ngobe Bugle              0            0              1
# 20087043 2008 Comarca Ngobe Bugle              0            0              1
# 20087044 2008 Comarca Ngobe Bugle              2            0              1
# 20087045 2008 Comarca Ngobe Bugle              1            0              1
#
# k                                  Males 09-13  Females 09-13  Males 14-18  \
# i        t    m
# 1997125  1997 Herrera                        1              0            0
# 1997160  1997 Herrera                        0              0            0
# 1997170  1997 Bocas Del Toro                 0              1            1
# 1997177  1997 Bocas Del Toro                 1              3            2
# 1997178  1997 Bocas Del Toro                 1              0            0
# ...                                        ...            ...          ...
# 20087041 2008 Comarca Ngobe Bugle            0              0            0
# 20087042 2008 Comarca Ngobe Bugle            1              1            0
# 20087043 2008 Comarca Ngobe Bugle            1              1            0
# 20087044 2008 Comarca Ngobe Bugle            0              0            0
# 20087045 2008 Comarca Ngobe Bugle            0              1            0
#
# k                                  Females 14-18  Males 19-30  Females 19-30  \
# i        t    m
# 1997125  1997 Herrera                          0            0              0
# 1997160  1997 Herrera                          0            0              0
# 1997170  1997 Bocas Del Toro                   1            0              0
# 1997177  1997 Bocas Del Toro                   0            0              2
# 1997178  1997 Bocas Del Toro                   1            2              0
# ...                                          ...          ...            ...
# 20087041 2008 Comarca Ngobe Bugle              0            1              2
# 20087042 2008 Comarca Ngobe Bugle              1            0              0
# 20087043 2008 Comarca Ngobe Bugle              2            0              0
# 20087044 2008 Comarca Ngobe Bugle              0            2              2
# 20087045 2008 Comarca Ngobe Bugle              0            0              0
#
# k                                  Males 31-50  Females 31-50  Males 51-99  \
# i        t    m
# 1997125  1997 Herrera                        0              1            1
# 1997160  1997 Herrera                        0              1            1
# 1997170  1997 Bocas Del Toro                 0              1            1
# 1997177  1997 Bocas Del Toro                 0              2            1
# 1997178  1997 Bocas Del Toro                 0              1            0
# ...                                        ...            ...          ...
# 20087041 2008 Comarca Ngobe Bugle            0              0            0
# 20087042 2008 Comarca Ngobe Bugle            1              1            0
# 20087043 2008 Comarca Ngobe Bugle            1              1            0
# 20087044 2008 Comarca Ngobe Bugle            0              0            0
# 20087045 2008 Comarca Ngobe Bugle            1              1            0
#
# k                                  Females 51-99  log HSize
# i        t    m
# 1997125  1997 Herrera                          0   1.098612
# 1997160  1997 Herrera                          1   1.098612
# 1997170  1997 Bocas Del Toro                   0   2.197225
# 1997177  1997 Bocas Del Toro                   0   2.944439
# 1997178  1997 Bocas Del Toro                   1   1.945910
# ...                                          ...        ...
# 20087041 2008 Comarca Ngobe Bugle              1   2.079442
# 20087042 2008 Comarca Ngobe Bugle              0   2.079442
# 20087043 2008 Comarca Ngobe Bugle              0   2.197225
# 20087044 2008 Comarca Ngobe Bugle              0   2.079442
# 20087045 2008 Comarca Ngobe Bugle              0   1.609438
#
# [18352 rows x 19 columns]

# %%
hh_characteristics.index.is_unique
# Out:
# True

# %%
from eep153_tools.sheets import read_sheets
# Get food prices and call it p
url = 'https://docs.google.com/spreadsheets/d/1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw/edit#gid=2085637103'
p = read_sheets(url,sheet='Food Prices',nheaders=2)

p.columns.names = ['t','m']
p.groupby(level='j').mean()

#use tranpose to switch columns and rows as the original structure of the dataframe was not applicable to use.
p = p.transpose()
if 'm' not in p.columns:
    p['m']=1

p=p.apply(lambda x: pd.to_numeric(x,errors='coerce'))
p=p.replace(0,np.nan)

# %%
p=p.T

# %%
pd.options.display.max_rows=1000

# %%
#p.xs('Aceite Vegetal',level='j').groupby('t',axis=1).median()

# %%
p_per_lb=p.groupby('t',axis=1).median().xs('pound',level='u')
# Out:
# /tmp/ipykernel_214/2715335141.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   p_per_lb=p.groupby('t',axis=1).median().xs('pound',level='u')

# %%
# Get FCT
fct = get_clean_sheet(InputFiles['FCT'][0],
                    sheet=InputFiles['FCT'][1])

fct = fct.set_index('j')
fct.columns.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# %%
# Get RDI
rdi = get_clean_sheet(InputFiles['Copy of RDI'][0],
                    sheet=InputFiles['Copy of RDI'][1])
rdi = rdi.set_index('n')
rdi.columns.name = 'k'

# %%
expenditures.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui             6.0        NaN        0.5  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971003 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971005 1997 Chíriqui             3.7        NaN        NaN  NaN
#
# j                       Alimento Infantil  Apio  Arroz  Arvejas  Azúcar  \
# i        t    m
# 19971000 1997 Chíriqui                2.7   0.3   7.25      NaN     1.6
# 19971001 1997 Chíriqui                NaN   NaN   4.80      NaN     NaN
# 19971002 1997 Chíriqui                NaN   NaN   6.00      NaN     2.0
# 19971003 1997 Chíriqui                NaN   NaN    NaN      NaN     NaN
# 19971005 1997 Chíriqui                NaN   NaN    NaN      NaN     4.5
#
# j                       Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                    ...
# 19971000 1997 Chíriqui        NaN  ...                       8.0
# 19971001 1997 Chíriqui        1.4  ...                       1.5
# 19971002 1997 Chíriqui        3.6  ...                       NaN
# 19971003 1997 Chíriqui        NaN  ...                       NaN
# 19971005 1997 Chíriqui        1.5  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro  Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui            0.7          NaN     NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN     0.3             NaN
# 19971002 1997 Chíriqui            3.5          NaN     NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN     NaN             NaN
# 19971005 1997 Chíriqui            0.7          NaN     NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN        0.8
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   1.0        NaN
#
# j                       Zapallo / Chayote  Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN   0.4
# 19971001 1997 Chíriqui                NaN   NaN
# 19971002 1997 Chíriqui                2.0   NaN
# 19971003 1997 Chíriqui                NaN   NaN
# 19971005 1997 Chíriqui                NaN   NaN
#
# [5 rows x 84 columns]

# %%
hh_characteristics.head()
# Out:
# k                            women  boys  men  girls  Males 00-03  \
# i       t    m
# 1997125 1997 Herrera             1     1    1      0            0
# 1997160 1997 Herrera             2     0    1      0            0
# 1997170 1997 Bocas Del Toro      1     3    1      4            1
# 1997177 1997 Bocas Del Toro      4     9    1      5            2
# 1997178 1997 Bocas Del Toro      2     1    2      2            0
#
# k                            Females 00-03  Males 04-08  Females 04-08  \
# i       t    m
# 1997125 1997 Herrera                     0            0              0
# 1997160 1997 Herrera                     0            0              0
# 1997170 1997 Bocas Del Toro              2            1              0
# 1997177 1997 Bocas Del Toro              1            4              1
# 1997178 1997 Bocas Del Toro              0            0              1
#
# k                            Males 09-13  Females 09-13  Males 14-18  \
# i       t    m
# 1997125 1997 Herrera                   1              0            0
# 1997160 1997 Herrera                   0              0            0
# 1997170 1997 Bocas Del Toro            0              1            1
# 1997177 1997 Bocas Del Toro            1              3            2
# 1997178 1997 Bocas Del Toro            1              0            0
#
# k                            Females 14-18  Males 19-30  Females 19-30  \
# i       t    m
# 1997125 1997 Herrera                     0            0              0
# 1997160 1997 Herrera                     0            0              0
# 1997170 1997 Bocas Del Toro              1            0              0
# 1997177 1997 Bocas Del Toro              0            0              2
# 1997178 1997 Bocas Del Toro              1            2              0
#
# k                            Males 31-50  Females 31-50  Males 51-99  \
# i       t    m
# 1997125 1997 Herrera                   0              1            1
# 1997160 1997 Herrera                   0              1            1
# 1997170 1997 Bocas Del Toro            0              1            1
# 1997177 1997 Bocas Del Toro            0              2            1
# 1997178 1997 Bocas Del Toro            0              1            0
#
# k                            Females 51-99  log HSize
# i       t    m
# 1997125 1997 Herrera                     0   1.098612
# 1997160 1997 Herrera                     1   1.098612
# 1997170 1997 Bocas Del Toro              0   2.197225
# 1997177 1997 Bocas Del Toro              0   2.944439
# 1997178 1997 Bocas Del Toro              1   1.945910

# %%
p_per_lb.columns=[1997,2003]

# %%
from cfe import regression as rgsn
import numpy as np

# Load a regression model from a pickle file that was named 'estimates.pickle' earlier.
r = rgsn.read_pickle('estimates.pickle')

# Use the loaded model to predict expenditures based on the model's estimates.
xhat = r.predicted_expenditures()

# Implied relative prices
p = np.exp(r.get_Ar())

# %%
xhat
# Out:
# i         t     m                    j
# 20081     2008  Bocas Del Toro       Aceite Vegetal               5.326744
#                                      Ajo                          0.686368
#                                      Arroz                        7.549828
#                                      Azúcar                       2.972885
#                                      Café Y Té                    2.636834
#                                                                     ...
# 20087040  2008  Comarca Ngobe Bugle  Queso (Blanco Y Amarillo)    1.720973
#                                      Raspados Y Duros             1.391364
#                                      Sal                          0.630284
#                                      Sardina Y Atún               3.746857
#                                      Sodas, Refrescos Y Jugos     2.617251
# Length: 417378, dtype: float64

# %%
xhat.unstack('j').xs(1997,level='t')/p_per_lb[1997]
# Out:
# j                        Aceite Vegetal  Aguacates  Ahí Verde       Ajo  \
# i        m
# 1997125  Herrera               1.302591        NaN        NaN  0.648874
# 1997160  Herrera               1.081041        NaN        NaN  0.557456
# 1997170  Bocas Del Toro        0.686893        NaN        NaN  0.373462
# 1997180  Bocas Del Toro        1.650482        NaN        NaN  0.796181
# 1997269  Chíriqui              1.291344        NaN        NaN  0.641654
# ...                                 ...        ...        ...       ...
# 19976665 Panamá                0.540010        NaN        NaN  0.362979
# 19976666 Panamá                0.743526        NaN        NaN  0.443518
# 19976667 Panamá                0.711743        NaN        NaN  0.428997
# 19976668 Panamá                0.706572        NaN        NaN  0.426155
# 19976669 Panamá                0.891750        NaN        NaN  0.544562
#
# j                        Alimento Infantil  Apio      Arroz  Arvejas  \
# i        m
# 1997125  Herrera                       NaN   NaN  27.405115      NaN
# 1997160  Herrera                       NaN   NaN  22.629801      NaN
# 1997170  Bocas Del Toro                NaN   NaN  23.068933      NaN
# 1997180  Bocas Del Toro                NaN   NaN  33.546540      NaN
# 1997269  Chíriqui                      NaN   NaN  18.348149      NaN
# ...                                    ...   ...        ...      ...
# 19976665 Panamá                        NaN   NaN   9.046374      NaN
# 19976666 Panamá                        NaN   NaN  12.815101      NaN
# 19976667 Panamá                        NaN   NaN  13.161689      NaN
# 19976668 Panamá                        NaN   NaN  13.119580      NaN
# 19976669 Panamá                        NaN   NaN  14.762201      NaN
#
# j                           Azúcar  Café Y Té  ...  Segundo otro  \
# i        m                                     ...
# 1997125  Herrera          6.432036   1.402235  ...           NaN
# 1997160  Herrera          5.316965   1.311137  ...           NaN
# 1997170  Bocas Del Toro  12.643680   0.926063  ...           NaN
# 1997180  Bocas Del Toro  16.484101   1.615524  ...           NaN
# 1997269  Chíriqui         5.514160   0.977074  ...           NaN
# ...                            ...        ...  ...           ...
# 19976665 Panamá           2.643939   0.668320  ...           NaN
# 19976666 Panamá           3.625360   0.852673  ...           NaN
# 19976667 Panamá           3.388701   0.693344  ...           NaN
# 19976668 Panamá           3.370511   0.689509  ...           NaN
# 19976669 Panamá           4.262574   1.015499  ...           NaN
#
# j                        Sodas, Refrescos Y Jugos  Tercer otro  Tomate  \
# i        m
# 1997125  Herrera                         7.047068          NaN     NaN
# 1997160  Herrera                         4.416370          NaN     NaN
# 1997170  Bocas Del Toro                  1.304553          NaN     NaN
# 1997180  Bocas Del Toro                  7.256709          NaN     NaN
# 1997269  Chíriqui                        4.017732          NaN     NaN
# ...                                           ...          ...     ...
# 19976665 Panamá                          1.795628          NaN     NaN
# 19976666 Panamá                          2.562676          NaN     NaN
# 19976667 Panamá                          2.632959          NaN     NaN
# 19976668 Panamá                          2.592718          NaN     NaN
# 19976669 Panamá                          3.824851          NaN     NaN
#
# j                        Viscera De Res  Visceras De Pollo O Gallina  Yuca  \
# i        m
# 1997125  Herrera                    NaN                          NaN   NaN
# 1997160  Herrera                    NaN                          NaN   NaN
# 1997170  Bocas Del Toro             NaN                          NaN   NaN
# 1997180  Bocas Del Toro             NaN                          NaN   NaN
# 1997269  Chíriqui                   NaN                          NaN   NaN
# ...                                 ...                          ...   ...
# 19976665 Panamá                     NaN                          NaN   NaN
# 19976666 Panamá                     NaN                          NaN   NaN
# 19976667 Panamá                     NaN                          NaN   NaN
# 19976668 Panamá                     NaN                          NaN   NaN
# 19976669 Panamá                     NaN                          NaN   NaN
#
# j                        Zanahoria  Zapallo / Chayote  Ñame
# i        m
# 1997125  Herrera               NaN                NaN   NaN
# 1997160  Herrera               NaN                NaN   NaN
# 1997170  Bocas Del Toro        NaN                NaN   NaN
# 1997180  Bocas Del Toro        NaN                NaN   NaN
# 1997269  Chíriqui              NaN                NaN   NaN
# ...                            ...                ...   ...
# 19976665 Panamá                NaN                NaN   NaN
# 19976666 Panamá                NaN                NaN   NaN
# 19976667 Panamá                NaN                NaN   NaN
# 19976668 Panamá                NaN                NaN   NaN
# 19976669 Panamá                NaN                NaN   NaN
#
# [4252 rows x 78 columns]

# %%
#xhat.unstack('j').xs(2003,level='t')/p_per_lb[2003]

# %%
#xhat.index

# %%
fct.head()
# Out:
# n                   Agua  Energía  Proteina  Grasa Total  Carbo-hidratos  \
# j
# Aceite Vegetal      0.00      884      0.00       100.00            0.00
# Aguacates          73.23      160      2.00        14.66            8.53
# Ahí Verde          93.89       20      0.86         0.17            3.64
# Ajo                63.80      134      5.30         0.20           29.30
# Alimento Infantil   3.00      510     12.50        27.00           54.30
#
# n                  Fibra Diet. total  Ceniza  Calcio  Fosforo  Hierro  ...  \
# j                                                                      ...
# Aceite Vegetal                   0.0    0.00       0        0    0.00  ...
# Aguacates                        6.7    1.58      12       52    0.55  ...
# Ahí Verde                        1.7    0.43      10       20    0.34  ...
# Ajo                              0.0    1.40      38      134    1.40  ...
# Alimento Infantil                0.0    3.20     530      420    9.00  ...
#
# n                  Colesterol  Potasio  Sodio  Zinc  Magnesio  Vit. B6  \
# j
# Aceite Vegetal              0        0      0  0.00         0     0.00
# Aguacates                   0      485      7  0.64        29     0.26
# Ahí Verde                   0      175      3  0.13        10     0.22
# Ajo                         0      529     19  1.00         0     0.00
# Alimento Infantil           0      600    180  6.00        55     0.30
#
# n                  Vit. B12  Ac. Fólico  Folato Equiv. FD  Fracción Comestible
# j
# Aceite Vegetal          0.0           0                 0                 1.00
# Aguacates               0.0           0                81                 0.74
# Ahí Verde               0.0           0                11                 0.82
# Ajo                     0.0           3                 0                 0.94
# Alimento Infantil       1.5          80               136                 1.00
#
# [5 rows x 28 columns]

# %%
rdi.head()
# Out:
# k        F 00-03  M 00-03  F 04-08  M 04-08  F 09-13  M 09-13  F 14-18  \
# n
# Energy    1000.0   1000.0   1200.0   1400.0   1600.0   1800.0   1800.0
# Protein     13.0     13.0     19.0     19.0     34.0     34.0     46.0
# Fiber       14.0     14.0     16.8     19.6     22.4     25.2     25.2
# Folate     150.0    150.0    200.0    200.0    300.0    300.0    400.0
# Calcium    700.0    700.0   1000.0   1000.0   1300.0   1300.0   1300.0
#
# k        M 14-18  F 19-30  M 19-30  F 31-50  M 31-50   F 51+   M 51+
# n
# Energy    2200.0   2000.0   2400.0   1800.0   2200.0  1600.0  2000.0
# Protein     52.0     46.0     56.0     46.0     56.0    46.0    56.0
# Fiber       30.8     28.0     33.6     25.2     30.8    22.4    28.0
# Folate     400.0    400.0    400.0    400.0    400.0   400.0   400.0
# Calcium   1300.0   1000.0   1000.0   1000.0   1000.0  1200.0  1000.0

# %%
# log_expenditures represents the logarithm of food expenditures.
log_expenditures = np.log(expenditures)

log_expenditures.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui        1.791759        NaN  -0.693147  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui        1.252763        NaN        NaN  NaN
# 19971003 1997 Chíriqui        1.252763        NaN        NaN  NaN
# 19971005 1997 Chíriqui        1.308333        NaN        NaN  NaN
#
# j                       Alimento Infantil      Apio     Arroz  Arvejas  \
# i        t    m
# 19971000 1997 Chíriqui           0.993252 -1.203973  1.981001      NaN
# 19971001 1997 Chíriqui                NaN       NaN  1.568616      NaN
# 19971002 1997 Chíriqui                NaN       NaN  1.791759      NaN
# 19971003 1997 Chíriqui                NaN       NaN       NaN      NaN
# 19971005 1997 Chíriqui                NaN       NaN       NaN      NaN
#
# j                         Azúcar  Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                              ...
# 19971000 1997 Chíriqui  0.470004        NaN  ...                  2.079442
# 19971001 1997 Chíriqui       NaN   0.336472  ...                  0.405465
# 19971002 1997 Chíriqui  0.693147   1.280934  ...                       NaN
# 19971003 1997 Chíriqui       NaN        NaN  ...                       NaN
# 19971005 1997 Chíriqui  1.504077   0.405465  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro    Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui      -0.356675          NaN       NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN -1.203973             NaN
# 19971002 1997 Chíriqui       1.252763          NaN       NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN       NaN             NaN
# 19971005 1997 Chíriqui      -0.356675          NaN       NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN  -0.223144
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   0.0        NaN
#
# j                       Zapallo / Chayote      Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN -0.916291
# 19971001 1997 Chíriqui                NaN       NaN
# 19971002 1997 Chíriqui           0.693147       NaN
# 19971003 1997 Chíriqui                NaN       NaN
# 19971005 1997 Chíriqui                NaN       NaN
#
# [5 rows x 84 columns]

# %%
# use is the intersection of indexs between log_expenditures and household characteristics.
use = log_expenditures.index.intersection(hh_characteristics.index)

log_expenditures = log_expenditures.loc[use,:]
hh_characteristics = hh_characteristics.loc[use,:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 2
#       1 # use is the intersection of indexs between log_expenditures and household characteristics.
# ----> 2 use = log_expenditures.index.intersection(hh_characteristics.index)
#       4 log_expenditures = log_expenditures.loc[use,:]
#       5 hh_characteristics = hh_characteristics.loc[use,:]
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:3502, in Index.intersection(self, other, sort)
#    3496 if len(self) == 0 or len(other) == 0:
#    3497     # fastpath; we need to be careful about having commutativity
#    3499     if self._is_multi or other._is_multi:
#    3500         # _convert_can_do_setop ensures that we have both or neither
#    3501         # We retain self.levels
# -> 3502         return self[:0].rename(result_name)
#    3504     dtype = self._find_common_type_compat(other)
#    3505     if self.dtype == dtype:
#    3506         # Slicing allows us to retain DTI/TDI.freq, RangeIndex
#    3507
#    (...)
#    3511         #     reason for this choice.
#    3512         #  2) The `step` we get in RangeIndex cases
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:1909, in Index.set_names(self, names, level, inplace)
#    1906 else:
#    1907     idx = self._view()
# -> 1909 idx._set_names(names, level=level)
#    1910 if not inplace:
#    1911     return idx
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/indexes/multi.py:1609, in MultiIndex._set_names(self, names, level, validate)
#    1607         raise ValueError("Length of names must match length of level.")
#    1608     if level is None and len(names) != self.nlevels:
# -> 1609         raise ValueError(
#    1610             "Length of names must match number of levels in MultiIndex."
#    1611         )
#    1613 if level is None:
#    1614     level = range(self.nlevels)
#
# ValueError: Length of names must match number of levels in MultiIndex.

# %%
log_expenditures = log_expenditures.stack()
hh_characteristics = hh_characteristics.stack()

# Check that indices are in right places!
assert log_expenditures.index.names == ['i','t','m','j']
assert hh_characteristics.index.names == ['i','t','m','k']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_214/112434866.py in ?()
# ----> 1 log_expenditures = log_expenditures.stack()
#       2 hh_characteristics = hh_characteristics.stack()
#       3
#       4 # Check that indices are in right places!
#
# /srv/conda/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'stack'

# %%
#set up regression
result = Regression(y = log_expenditures,d = hh_characteristics)

# %%
#get regression results
result.predicted_expenditures()

# %%
# use the graph to compare log food expenditures and actual expenditures
# %matplotlib widget
df = pd.DataFrame({'y':log_expenditures,'yhat':result.get_predicted_log_expenditures()})
df.plot.scatter(x='yhat',y='y')

# %%
#get the value of beta - As shown above, beta captures how the household's overall wealth affects its expenditures on food. 
result.get_beta().sort_values()

# %%
#graph beta
result.graph_beta()

# %%
#get the value of gamma - As shown above, gamma captures how household characteristics affects its expenditures on food. 
result.gamma

# %%
#To save result
result.to_pickle('estimates.pickle')

result = cfe.regression.read_pickle('estimates.pickle')

# %%
import cfe

result = cfe.Regression(y=np.log(expenditures.stack()),d=hh_characteristics)

result.get_beta().sort_values(ascending=False) # Check sanity...

# %%
result.to_pickle('./foo.pickle')

# %%
p

# %%
from cfe import regression as rgsn
import numpy as np

# Load a regression model from a pickle file that was named 'estimates.pickle' earlier.
r = rgsn.read_pickle('estimates.pickle')

# Use the loaded model to predict expenditures based on the model's estimates.
xhat = r.predicted_expenditures()

# Implied relative prices
p = np.exp(r.get_Ar())

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

use = 'Arroz'  # Put the food item that we want demand curve for here. 
               # 'Arroz' is translated to 'rice' in English. 

# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p.groupby(level='j').mean()

def my_prices(p0,p=pbar,j='Arroz'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Demand for Rice for household at median budget
plt.plot([r.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Rice for household at 25% percentile
plt.plot([r.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Rice for household at 75% percentile
plt.plot([r.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded")

# %%
p=p.median()

# %%
# Get food prices and call it p
url = 'https://docs.google.com/spreadsheets/d/1gcAb2jlGQNrD2zrrTEbjL47vbXoxCHkkjHSYzD0-Tiw/edit#gid=2085637103'
p = read_sheets(url,sheet='Food Prices',nheaders=2)

p.columns.names = ['t','m']
p.groupby(level='j').mean()

#use tranpose to switch columns and rows as the original structure of the dataframe was not applicable to use.
p = p.transpose()
if 'm' not in p.columns:
    p['m']=1

p=p.apply(lambda x: pd.to_numeric(x,errors='coerce'))
p=p.replace(0,np.nan)

# %%
p

# %%
# Get FCT
fct = get_clean_sheet(InputFiles['FCT'][0],
                    sheet=InputFiles['FCT'][1])

fct = fct.set_index('j')
fct.columns.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))
fct.head(10)

# %%
#use = fct.index.intersection(qhat.columns)


#nutrients = qhat[use]@fct.loc[use,:]
#nutrients.mean()    # NB: Nutrients are for past /week/ for entire household. (Depends on dataset)

# %%
xhat

# %%
fct

# %%
# Get RDI
rdi = get_clean_sheet(InputFiles['Copy of RDI'][0],
                    sheet=InputFiles['Copy of RDI'][1])
rdi = rdi.set_index('n')
rdi.columns.name = 'k'
rdi

# %%
# Get Household characteristics 
hh_characteristics = get_clean_sheet(InputFiles['Household Characteristics'][0],
                    sheet=InputFiles['Household Characteristics'][1])

if 'm' not in hh_characteristics.columns:
    hh_characteristics['m'] = 1

hh_characteristics = hh_characteristics.set_index(['i','t','m'])
hh_characteristics.columns.name = 'k'
#hh_characteristics.name = 'value'  

hh_characteristics = hh_characteristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))
print(hh_characteristics)

# %%
# Get the intersection of column names between rdi and hh_characteristics DataFrames
common_columns = list(set(rdi.columns) & set(hh_characteristics.columns))

# Select only the common columns from hh_characteristics DataFrame
hh_characteristics = hh_characteristics[common_columns]

# Debugging: Print out common columns
print("Common columns:", common_columns)

# Rename columns in hh_characteristics DataFrame using the mapping dictionary
hh_characteristics = hh_characteristics.rename(columns=column_mapping)

# Debugging: Print out mapping dictionary and renamed columns
print("Column mapping dictionary:", column_mapping)
print("Columns in hh_characteristics DataFrame after renaming:", hh_characteristics.columns.tolist())

# Now hh_characteristics DataFrame should have column names matching the rdi DataFrame
print("Columns in rdi DataFrame:", rdi.columns.tolist())
print("Columns in hh_characteristics DataFrame:", hh_characteristics.columns.tolist())

# Print out hh_characteristics DataFrame
print("hh_characteristics DataFrame:")
print(hh_characteristics)

# %%
# Get the intersection of column names between rdi and hh_characteristics DataFrames
common_columns = list(set(rdi.columns) & set(hh_characteristics.columns))

# Select only the common columns from hh_characteristics DataFrame
hh_characteristics = hh_characteristics[common_columns]

# Now both DataFrames have the same columns

# Rename columns in hh_characteristics DataFrame using the mapping dictionary
hh_characteristics = hh_characteristics.rename(columns=column_mapping)

# Now hh_characteristics DataFrame should have column names matching the rdi DataFrame
print("Columns in rdi DataFrame:", rdi.columns.tolist())
print("Columns in hh_characteristics DataFrame:", hh_characteristics.columns.tolist())
hh_characteristics

# Define a mapping dictionary to rename columns in hh_characteristics DataFrame
column_mapping = {
    'women': 'F 51+',
    'girls': 'F 14-18',
    'men': 'M 51+',
    'boys': 'M 14-18',
    'Males 00-03': 'M 00-03',
    'Females 00-03': 'F 00-03',
    'Males 04-08': 'M 04-08',
    'Females 04-08': 'F 04-08',
    'Males 09-13': 'M 09-13',
    'Females 09-13': 'F 09-13',
    'Males 14-18': 'M 14-18',
    'Females 14-18': 'F 14-18',
    'Males 19-30': 'M 19-30',
    'Females 19-30': 'F 19-30',
    'Males 31-50': 'M 31-50',
    'Females 31-50': 'F 31-50',
    'Males 51-99': 'M 51+',
    'Females 51-99': 'F 51+',
    'log HSize': 'log HSize'}
hh_characteristics

# %%
new_column_names = [
"Females 00-03", "Males 00-03", "Females 04-08", "Males 04-08", "Females 09-13", "Males 09-13", "Females 14-18", "Males 14-18",  "Females 19-30", "Males 19-30", "Females 31-50", "Males 31-50",  "Females 51-99", "Males 51-99"]
column_name_mapping = {old: new for old, new in zip(rdi.columns, new_column_names)}
rdi.rename(columns=column_name_mapping, inplace=True)

print (rdi.head())

new_column_names = [
"Females 00-03", "Males 00-03", "Females 04-08", "Males 04-08", "Females 09-13", "Males 09-13", "Females 14-18", "Males 14-18",  "Females 19-30", "Males 19-30", "Females 31-50", "Males 31-50",  "Females 51-99", "Males 51-99"]
column_name_mapping = {old: new for old, new in zip(hh_characteristics.columns, new_column_names)}
hh_characteristics.rename(columns=column_name_mapping, inplace=True)

print (hh_characteristics.head())

# %%
xhat = r.predicted_expenditures()
prices_kg = read_sheets(key='https://docs.google.com/spreadsheets/d/1P7OQG9cmBSS4dY6ZPI1HOPHW9shCTSkguDVnUCuh3Is/edit#gid=199254621 ', sheet="Food Prices in Kilograms 1")
if 'm' not in prices_kg.columns:  
    prices_kg['m'] = 1
prices_kg

prices_kg = prices_kg.set_index(['t','m'])
prices_kg.columns.name = 'j'

prices_kg = prices_kg.apply(lambda x: pd.to_numeric(x,errors='coerce'))
prices_kg = prices_kg.replace(0,np.nan)

qhat = (xhat.unstack('j')/prices_kg).dropna(how='all')
qhat = qhat.loc[:,qhat.count()>0]

use = fct.index.intersection(qhat.columns)

nutrients = qhat[use]@fct.loc[use,:]

nutrients.mean()

hh_characteristics = get_clean_sheet(InputFiles['Household Characteristics'][0],
                    sheet=InputFiles['Household Characteristics'][1])

if 'm' not in hh_characteristics.columns:
    hh_characteristics['m'] = 1

hh_characteristics = hh_characteristics.set_index(['i','t','m'])
hh_characteristics.columns.name = 'k'

hh_characteristics = hh_characteristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))

hh_characteristics = hh_characteristics[rdi.columns.tolist()]

hh_rdi = hh_characteristics@rdi.T

#check recommended weekly intake?
hh_rwi = hh_rdi*7
use_nutrients = nutrients.columns.intersection(hh_rwi.columns)
nutrient_ratio = (nutrients[use_nutrients]/hh_rwi[use_nutrients]).dropna()

nutrient_ratio
